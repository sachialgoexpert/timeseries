# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
import padas_datareader as pdr
df=pdr.get_data_yahoo('AAPL',start='2020-01-01',end='2025-01-01')
df.head()
